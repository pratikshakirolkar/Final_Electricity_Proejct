# %% [markdown]
# <a href="https://colab.research.google.com/github/pratikshakirolkar/Final_Electricity_Project/blob/main/Basic_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing_Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
#Dataset
data=pd.read_csv("/content/State_Wise_Data.csv")

# %%
data.rename(columns={"Unnamed: 0":"Date"},inplace=True)

# %%
#creating_new_column
data['Date']=pd.to_datetime(data["Date"],dayfirst=True)
data["year"]=data["Date"].dt.year
data["month"]=data["Date"].dt.month
data["day"]=data["Date"].dt.day

# %%
#specifyfirstvalues
data.head(10)
# Out:
#         Date  Punjab  Haryana  Rajasthan  Delhi     UP  Uttarakhand     HP  \
# 0 2019-01-01   121.3    134.5      230.2   83.0  315.2         38.3  29.17
# 1 2019-01-02   119.9    130.3      234.1   85.8  313.9         40.7  30.00
# 2 2019-01-03   121.9    133.5      240.2   85.5  311.8         39.3  30.10
# 3 2019-01-04   118.8    128.2      239.8   83.5  320.7         38.1  30.10
# 4 2019-01-05   121.0    127.5      239.1   79.2  299.0         39.2  30.20
# 5 2019-01-06   121.4    132.6      240.4   76.6  286.8         39.2  31.00
# 6 2019-01-07   118.0    132.1      241.9   71.1  294.2         40.1  30.10
# 7 2019-01-08   107.5    121.4      237.2   69.0  289.4         37.0  29.20
# 8 2019-01-09   132.5    148.2      197.0   89.2  258.6         35.9  25.30
# 9 2019-01-10   131.5    157.0      199.9   92.8  284.2         35.3  26.50
#
#     J&K  Chandigarh  ...  Arunachal Pradesh  Assam  Manipur  Meghalaya  \
# 0  51.2         4.8  ...                2.0   22.3      2.5        5.9
# 1  52.5         5.0  ...                2.1   21.7      2.7        6.1
# 2  54.1         4.9  ...                2.2   23.4      2.4        6.5
# 3  53.2         4.8  ...                2.2   21.7      2.4        6.3
# 4  51.5         4.3  ...                2.2   22.5      2.7        5.7
# 5  53.2         4.3  ...                2.2   21.7      2.7        6.2
# 6  53.3         4.0  ...                2.2   21.4      2.5        6.1
# 7  51.2         3.8  ...                2.3   20.7      2.6        6.2
# 8  37.9         3.9  ...                2.1   25.8      2.3        6.0
# 9  31.7         3.9  ...                2.1   25.8      2.4        6.2
#
#    Mizoram  Nagaland  Tripura  year  month  day
# 0      1.7       2.0      3.3  2019      1    1
# 1      1.9       2.2      3.4  2019      1    2
# 2      1.8       2.2      3.6  2019      1    3
# 3      1.7       2.2      3.5  2019      1    4
# 4      1.8       2.3      3.5  2019      1    5
# 5      1.9       2.3      3.3  2019      1    6
# 6      1.8       2.3      3.3  2019      1    7
# 7      1.8       2.1      3.3  2019      1    8
# 8      1.7       2.4      4.2  2019      1    9
# 9      1.7       2.1      4.3  2019      1   10
#
# [10 rows x 37 columns]

# %%
#specifylastvalues
data.tail()
# Out:
#           Date  Punjab  Haryana  Rajasthan  Delhi     UP  Uttarakhand    HP  \
# 726 2020-12-27   103.7    110.4      211.4   63.8  229.9         33.4  29.3
# 727 2020-12-28    97.2    101.7      212.7   62.0  234.2         32.7  27.6
# 728 2020-12-29   237.2    214.1      232.7  128.5  421.3         42.0  29.9
# 729 2020-12-30   251.9    220.1      246.5  126.9  437.4         43.3  31.6
# 730 2020-12-31   255.0    223.2      253.5  134.9  424.0         44.3  31.6
#
#       J&K  Chandigarh  ...  Arunachal Pradesh  Assam  Manipur  Meghalaya  \
# 726  44.2         3.8  ...                2.0   20.1      2.6        5.8
# 727  47.7         3.4  ...                2.0   19.7      2.5        6.0
# 728  40.0         6.4  ...                2.0   34.2      2.4        5.3
# 729  42.8         6.4  ...                2.3   35.0      2.4        5.6
# 730  42.9         6.7  ...                2.2   34.7      2.5        5.7
#
#      Mizoram  Nagaland  Tripura  year  month  day
# 726      2.0       2.1      3.4  2020     12   27
# 727      1.7       2.1      3.4  2020     12   28
# 728      1.7       2.1      4.9  2020     12   29
# 729      1.8       2.1      4.9  2020     12   30
# 730      1.7       2.2      5.0  2020     12   31
#
# [5 rows x 37 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               731 non-null    datetime64[ns]
#  1   Punjab             731 non-null    float64
#  2   Haryana            731 non-null    float64
#  3   Rajasthan          731 non-null    float64
#  4   Delhi              731 non-null    float64
#  5   UP                 731 non-null    float64
#  6   Uttarakhand        731 non-null    float64
#  7   HP                 731 non-null    float64
#  8   J&K                731 non-null    float64
#  9   Chandigarh         731 non-null    float64
#  10  Chhattisgarh       731 non-null    float64
#  11  Gujarat            731 non-null    float64
#  12  MP                 731 non-null    float64
#  13  Maharashtra        731 non-null    float64
#  14  Goa                731 non-null    float64
#  15  DNH                731 non-null    float64
#  16  Andhra Pradesh     731 non-null    float64
#  17  Telangana          731 non-null    float64
#  18  Karnataka          731 non-null    float64
#  19  Kerala             731 non-null    float64
#  20  Tamil Nadu         731 non-null    float64
#  21  Pondy              731 non-null    float64
#  22  Bihar              731 non-null    float64
#  23  Jharkhand          731 non-null    float64
#  24  Odisha             731 non-null    float64
#  25  West Bengal        731 non-null    float64
#  26  Sikkim             731 non-null    float64
#  27  Arunachal Pradesh  731 non-null    float64
#  28  Assam              731 non-null    float64
#  29  Manipur            731 non-null    float64
#  30  Meghalaya          731 non-null    float64
#  31  Mizoram            731 non-null    float64
#  32  Nagaland           731 non-null    float64
#  33  Tripura            731 non-null    float64
#  34  year               731 non-null    int64
#  35  month              731 non-null    int64
#  36  day                731 non-null    int64
# dtypes: datetime64[ns](1), float64(33), int64(3)
# memory usage: 211.4 KB

# %%
#anynullvalue
data.isnull()
# Out:
#       Date  Punjab  Haryana  Rajasthan  Delhi     UP  Uttarakhand     HP  \
# 0    False   False    False      False  False  False        False  False
# 1    False   False    False      False  False  False        False  False
# 2    False   False    False      False  False  False        False  False
# 3    False   False    False      False  False  False        False  False
# 4    False   False    False      False  False  False        False  False
# ..     ...     ...      ...        ...    ...    ...          ...    ...
# 726  False   False    False      False  False  False        False  False
# 727  False   False    False      False  False  False        False  False
# 728  False   False    False      False  False  False        False  False
# 729  False   False    False      False  False  False        False  False
# 730  False   False    False      False  False  False        False  False
#
#        J&K  Chandigarh  ...  Arunachal Pradesh  Assam  Manipur  Meghalaya  \
# 0    False       False  ...              False  False    False      False
# 1    False       False  ...              False  False    False      False
# 2    False       False  ...              False  False    False      False
# 3    False       False  ...              False  False    False      False
# 4    False       False  ...              False  False    False      False
# ..     ...         ...  ...                ...    ...      ...        ...
# 726  False       False  ...              False  False    False      False
# 727  False       False  ...              False  False    False      False
# 728  False       False  ...              False  False    False      False
# 729  False       False  ...              False  False    False      False
# 730  False       False  ...              False  False    False      False
#
#      Mizoram  Nagaland  Tripura   year  month    day
# 0      False     False    False  False  False  False
# 1      False     False    False  False  False  False
# 2      False     False    False  False  False  False
# 3      False     False    False  False  False  False
# 4      False     False    False  False  False  False
# ..       ...       ...      ...    ...    ...    ...
# 726    False     False    False  False  False  False
# 727    False     False    False  False  False  False
# 728    False     False    False  False  False  False
# 729    False     False    False  False  False  False
# 730    False     False    False  False  False  False
#
# [731 rows x 37 columns]

# %%
data.describe()
# Out:
#            Punjab     Haryana   Rajasthan       Delhi          UP  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   139.389740  136.908345  218.889603   81.492202  308.838988
# std     54.783306   36.658950   25.515858   24.579907   62.617567
# min     56.100000   64.800000  105.800000   41.800000  186.800000
# 25%    104.600000  114.550000  207.600000   63.400000  263.300000
# 50%    117.700000  125.300000  222.500000   72.000000  288.000000
# 75%    150.650000  155.000000  237.050000   98.800000  351.900000
# max    300.000000  237.200000  278.000000  147.100000  471.800000
#
#        Uttarakhand          HP         J&K  Chandigarh  Chhattisgarh  ...  \
# count   731.000000  731.000000  731.000000  731.000000    731.000000  ...
# mean     35.873051   26.564391   44.242681    4.092886     83.365937  ...
# std       6.303098    4.527883    4.622439    1.089327      9.651465  ...
# min      16.500000   11.800000   17.800000    2.200000     37.200000  ...
# 25%      33.550000   25.300000   41.450000    3.300000     75.700000  ...
# 50%      36.500000   27.900000   44.100000    3.800000     82.100000  ...
# 75%      39.850000   29.600000   47.300000    4.700000     90.250000  ...
# max      53.200000   34.000000   54.200000    7.400000    111.600000  ...
#
#        Arunachal Pradesh       Assam     Manipur   Meghalaya     Mizoram  \
# count         731.000000  731.000000  731.000000  731.000000  731.000000
# mean            2.114090   24.875923    2.498358    5.683037    1.705062
# std             0.205623    4.501905    0.219208    0.685495    0.139918
# min             1.200000   12.200000    1.500000    3.200000    1.200000
# 25%             2.000000   22.100000    2.400000    5.300000    1.600000
# 50%             2.100000   23.500000    2.500000    5.800000    1.700000
# 75%             2.200000   27.200000    2.600000    6.100000    1.800000
# max             2.700000   38.000000    3.200000    6.900000    2.200000
#
#          Nagaland     Tripura         year       month         day
# count  731.000000  731.000000   731.000000  731.000000  731.000000
# mean     2.167305    4.086594  2019.500684    6.519836   15.738714
# std      0.135427    0.721631     0.500342    3.451913    8.809949
# min      1.700000    1.400000  2019.000000    1.000000    1.000000
# 25%      2.100000    3.500000  2019.000000    4.000000    8.000000
# 50%      2.200000    3.900000  2020.000000    7.000000   16.000000
# 75%      2.200000    4.600000  2020.000000   10.000000   23.000000
# max      2.700000    6.600000  2020.000000   12.000000   31.000000
#
# [8 rows x 36 columns]

# %%
#Dataset
long_data=pd.read_csv("/content/state-wise-power-consumption-in-india.csv")

# %%
#Creating_new_columns
long_data['Dates']=pd.to_datetime(long_data["Dates"],dayfirst=True)
long_data["year"]=long_data["Dates"].dt.year
long_data["month"]=long_data["Dates"].dt.month
long_data["day"]=long_data["Dates"].dt.day
long_data.drop(["latitude","longitude"],axis=1,inplace=True)

# %%
#specifyfirstvalues
long_data.head(10)
# Out:
#          States Regions      Dates  Usage  year  month  day
# 0        Punjab      NR 2019-01-02  119.9  2019      1    2
# 1       Haryana      NR 2019-01-02  130.3  2019      1    2
# 2     Rajasthan      NR 2019-01-02  234.1  2019      1    2
# 3         Delhi      NR 2019-01-02   85.8  2019      1    2
# 4            UP      NR 2019-01-02  313.9  2019      1    2
# 5   Uttarakhand      NR 2019-01-02   40.7  2019      1    2
# 6            HP      NR 2019-01-02   30.0  2019      1    2
# 7           J&K      NR 2019-01-02   52.5  2019      1    2
# 8    Chandigarh      NR 2019-01-02    5.0  2019      1    2
# 9  Chhattisgarh      WR 2019-01-02   78.7  2019      1    2

# %%
#specifylastvalues
long_data.tail()
# Out:
#           States Regions      Dates  Usage  year  month  day
# 16594    Manipur     NER 2020-12-05    2.5  2020     12    5
# 16595  Meghalaya     NER 2020-12-05    5.8  2020     12    5
# 16596    Mizoram     NER 2020-12-05    1.6  2020     12    5
# 16597   Nagaland     NER 2020-12-05    2.1  2020     12    5
# 16598    Tripura     NER 2020-12-05    3.3  2020     12    5

# %%
long_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16599 entries, 0 to 16598
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   States   16599 non-null  object
#  1   Regions  16599 non-null  object
#  2   Dates    16599 non-null  datetime64[ns]
#  3   Usage    16599 non-null  float64
#  4   year     16599 non-null  int64
#  5   month    16599 non-null  int64
#  6   day      16599 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 907.9+ KB

# %%
#anynullvalue
long_data.isnull()
# Out:
#        States  Regions  Dates  Usage   year  month    day
# 0       False    False  False  False  False  False  False
# 1       False    False  False  False  False  False  False
# 2       False    False  False  False  False  False  False
# 3       False    False  False  False  False  False  False
# 4       False    False  False  False  False  False  False
# ...       ...      ...    ...    ...    ...    ...    ...
# 16594   False    False  False  False  False  False  False
# 16595   False    False  False  False  False  False  False
# 16596   False    False  False  False  False  False  False
# 16597   False    False  False  False  False  False  False
# 16598   False    False  False  False  False  False  False
#
# [16599 rows x 7 columns]

# %%
long_data.describe()
# Out:
#               Usage          year         month           day
# count  16599.000000  16599.000000  16599.000000  16599.000000
# mean     103.001862   2019.286282      5.910537     15.318091
# std      116.044056      0.452037      3.461615      9.056657
# min        0.300000   2019.000000      1.000000      1.000000
# 25%        6.700000   2019.000000      3.000000      6.000000
# 50%       64.400000   2019.000000      5.000000     16.000000
# 75%      173.900000   2020.000000      9.000000     23.000000
# max      522.100000   2020.000000     12.000000     31.000000

# %% [markdown]
# Top 10 states that consume maximum power yearly.

# %%
# print("***************2020****************")
usage2020=dict()
for i in (long_data.States.unique()):
    a=long_data[(long_data["States"]==i)&(long_data["year"]==2020)]
    b=a.Usage.sum()
    usage2020.update({i:b})
# print(usage2020)
# print("***************2019****************")
usage2019=dict()
for i in (long_data.States.unique()):
    a=long_data[(long_data["States"]==i)&(long_data["year"]==2019)]
    b=a.Usage.sum()
    usage2019.update({i:b})
# print(usage2019)

# %%
table3=pd.DataFrame.from_dict(usage2020,orient="index")
table4=pd.DataFrame.from_dict(usage2019,orient="index")

# %%
table3.rename(columns={0:'toat usage in 2020'},inplace=True)
table4.rename(columns={0:'toat usage in 2019'},inplace=True)

# %%
table3.sort_values(by=['toat usage in 2020'],ascending=False,inplace=True)
table4.sort_values(by=['toat usage in 2019'],ascending=False,inplace=True)

# %% [markdown]
# TOP 10 Stated that consume maximum power in 2020

# %%
print('Top 10 states that consume maximum power in 2020')
table3.head(10)
# Out:
# Top 10 states that consume maximum power in 2020
#                 toat usage in 2020
# Maharashtra                62163.1
# Gujarat                    47131.5
# UP                         45270.4
# Tamil Nadu                 44551.3
# Rajasthan                  31738.2
# MP                         29791.8
# Karnataka                  29588.8
# Telangana                  26615.7
# Andhra Pradesh             25507.4
# Punjab                     21360.5

# %% [markdown]
# TOP 10 Stated that consume maximum power in 2019

# %%
print('Top 10 states that consume maximum power in 2019')
table4.head(10)
# Out:
# Top 10 states that consume maximum power in 2019
#                 toat usage in 2019
# Maharashtra               154916.7
# Gujarat                   115357.4
# UP                        112689.9
# Tamil Nadu                106720.2
# Rajasthan                  78138.8
# MP                         74974.6
# Karnataka                  73076.9
# Telangana                  67449.6
# Andhra Pradesh             63097.0
# West Bengal                49868.7

# %% [markdown]
# Barplot Visualization Top 10 states that consume maximum power in 2019 & 2020

# %%
#barplot
table5=table4.head(10)
plt.figure(figsize=(15, 5))
sns.barplot(y="toat usage in 2019",x=table5.index,data=table5)
print("Top 10 states that consume maximum power in 2019")
# Out:
# Top 10 states that consume maximum power in 2019

# %%
table6=table3.head(10)
plt.figure(figsize=(15, 5))
sns.barplot(y="toat usage in 2020",x=table6.index,data=table6)
print("Top 10 states that consume maximum power in 2020")
# Out:
# Top 10 states that consume maximum power in 2020

# %% [markdown]
# Top 10 states that consume least power yearly.

# %%
print('Top 10 states that consume least power in 2020')
table7=table3.tail(10)
table7
# Out:
# Top 10 states that consume least power in 2020
#                    toat usage in 2020
# Goa                            1573.4
# Pondy                          1105.6
# Meghalaya                       820.7
# Chandigarh                      610.8
# Tripura                         572.5
# Manipur                         360.2
# Nagaland                        310.9
# Arunachal Pradesh               306.9
# Mizoram                         244.0
# Sikkim                          182.2

# %%
print('Top 10 states that consume least power in 2019')
table8=table4.tail(10)
table8
# Out:
# Top 10 states that consume least power in 2019
#                    toat usage in 2019
# Goa                            4006.5
# Pondy                          2653.3
# Meghalaya                      2018.1
# Tripura                        1482.5
# Chandigarh                     1472.4
# Manipur                         894.6
# Nagaland                        776.8
# Arunachal Pradesh               754.0
# Mizoram                         614.3
# Sikkim                          466.4

# %% [markdown]
# Barplot Visualization Top 10 states that consume least power in 2019 & 2020

# %%
plt.figure(figsize=(15, 5))
sns.barplot(y="toat usage in 2019",x=table8.index,data=table8)
print("Top 10 states that consume least power in 2019")
# Out:
# Top 10 states that consume least power in 2019

# %%
plt.figure(figsize=(15, 5))
sns.barplot(y="toat usage in 2020",x=table7.index,data=table7)
print("Top 10 states that consume least power in 2020")
# Out:
# Top 10 states that consume least power in 2020

# %% [markdown]
# Which region consumes maximum & minimum power yearly?

# %%
c=dict()
for i in (long_data.Regions.unique()):
    a=long_data[(long_data["Regions"]==i)&(long_data["year"]==2020)]
    b=a.Usage.sum()
    c.update({i:b})
    
print(c)
# Out:
# {'NR': 147559.8, 'WR': 155089.3, 'SR': 137883.39999999997, 'ER': 46799.4, 'NER': 6190.7}

# %%
d=dict()
for i in (long_data.Regions.unique()):
    a=long_data[(long_data["Regions"]==i)&(long_data["year"]==2019)]
    b=a.Usage.sum()
    d.update({i:b})
    
print(d)
# Out:
# {'NR': 358694.8, 'WR': 385280.5, 'SR': 338795.20000000007, 'ER': 117915.1, 'NER': 15519.7}

# %%
print(f" maximum power consumed in 2020 is {c[max(c)]} by {max(c)} region\n minmum power consumed in 2020 is {c[min(c)]} by {min(c)} region  ")
# Out:
#  maximum power consumed in 2020 is 155089.3 by WR region
#  minmum power consumed in 2020 is 46799.4 by ER region

# %%
print(
f" maximum power consumed in 2019 is {d[max(d)]} by {max(d)} region\n minmum power consumed in 2019 is {d[min(d)]} by {min(d)} region  ")
# Out:
#  maximum power consumed in 2019 is 385280.5 by WR region
#  minmum power consumed in 2019 is 117915.1 by ER region

# %%
table1=pd.DataFrame.from_dict(c,orient="index")
table2=pd.DataFrame.from_dict(d,orient="index")

# %%
table1.rename(columns={0:"total usages (2020)"},inplace=True)
table2.rename(columns={0:"total usages (2019)"},inplace=True)

# %%
table1.head(2)
# Out:
#     total usages (2020)
# NR             147559.8
# WR             155089.3

# %% [markdown]
# Region wise total Usage in 2020

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x="total usages (2020)",y=table1.index,data=table1)
# Out:
# <AxesSubplot:xlabel='total usages (2020)'>

# %% [markdown]
# Region wise total Usage in 2019

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x="total usages (2019)",y=table2.index,data=table2)
# Out:
# <AxesSubplot:xlabel='total usages (2019)'>

# %% [markdown]
# In which months do you see a rise in consumption?

# %%
dict2019=dict()
for i in range(1,13):
    m=long_data[(long_data["month"]==i)&(long_data["year"]==2019)]
    n=m["Usage"].sum()
    dict2019.update({i:n})
dict2020=dict()
for i in range(1,13):
    m=long_data[(long_data["month"]==i)&(long_data["year"]==2020)]
    n=m["Usage"].sum()
    dict2020.update({i:n})

# %%
month=["jan","feb",'march',"april","may","june","july","aug","sep","oct","nov","dec"]

# %%
list1=list(dict2019.values())
list2=list(dict2020.values())

# %%
A=max(list1)
B=list1.index(A)
C=month[B]
x=max(list2)
y=list2.index(x)
z=month[y]

# %% [markdown]
# Maximum rise in consumption month 2019

# %%
print(f"maximum rise in consumption is in month of {C} 2019")
# Out:
# maximum rise in consumption is in month of july 2019

# %%
print(f"maximum rise in consumption is in month of {z} 2020")
# Out:
# maximum rise in consumption is in month of jan 2020

# %% [markdown]
# Visualization- maximum rise in consumption 2019

# %%
plt.figure(figsize = (15, 5))
plt.bar(month,list1,width = 0.4)
 
plt.ylabel("usages")
plt.xlabel("month")
plt.title("maximum rise in consumption 2019")
plt.show()

# %% [markdown]
# Visualization- maximum rise in consumption 2020

# %%
plt.figure(figsize = (15, 5))
plt.bar(month,list2,width = 0.4)
 
plt.ylabel("usages")
plt.xlabel("month")
plt.title("maximum rise in consumption in 2020")
plt.show()

# %%
#Histogram and Countplots
def histograms_and_countplots(column, data, columns_to_exclude):
    if column not in columns_to_exclude:
        if data[column].dtype not in ['int64', 'float64']:
            f, axes = plt.subplots(1,1,figsize=(15,5))
            sns.countplot(x=column, data = data)
            plt.xticks(rotation=90)
            plt.suptitle(column,fontsize=20)
            plt.show()
        else:
            g = sns.FacetGrid(data, margin_titles=True, aspect=4, height=3)
            g.map(plt.hist,column,bins=100)
            plt.show()
        plt.show()

# %%
columns_to_exclude = ['Dates','day','month','year','Usage' ]


for column in long_data.columns:
    histograms_and_countplots(column, long_data, columns_to_exclude)

# %%
#Compared 2019 and 2020 Year Usages of electricity
plt.figure(figsize=(8,8))
ax=sns.countplot(data=long_data, x='Regions', hue='year')
ax.set_ylabel('Usage')
bars = ax.patches
half = int(len(bars)/2)
left_bars = bars[:half]
right_bars = bars[half:]

# %% [markdown]
# In which months do you see a decline in consumption

# %%
a=min(list1)
b=list1.index(a)
c=month[b]
X=min(list2)
Y=list2.index(X)
Z=month[Y]
print(f"min rise in consumption is in month of {c} 2019")
print(f"min rise in consumption is in month of {Z} 2020")
# Out:
# min rise in consumption is in month of feb 2019
# min rise in consumption is in month of june 2020

# %%
plt.figure(figsize = (15, 5))
plt.bar(month,list1,width = 0.4)
 
plt.ylabel("usages")
plt.xlabel("month")
plt.title("min rise in consumption 2019")
plt.show()

# %%
plt.figure(figsize = (15, 5))
plt.bar(month,list1,width = 0.4)
 
plt.ylabel("usages")
plt.xlabel("month")
plt.title("min rise in consumption 2019")
plt.show()

# %% [markdown]
# Contrast between consumption during lockdown and without lockdown. (Compare the values in march-may 2019 and march-may 2020)

# %%
print(f"total consumption in march-may 2019 is {list1[2]+list1[3]+list1[4]}  ")
# Out:
# total consumption in march-may 2019 is 304712.4

# %%
print(f"total consumption in march-may 2020 is {list2[2]+list2[3]+list2[4]}  ")
# Out:
# total consumption in march-may 2020 is 208813.7

# %%
diff=((list1[2]+list1[3]+list1[4])-(list2[2]+list2[3]+list2[4]))
print(f"Contrast between consumption during lockdown and without lockdown is {diff}  ")
# Out:
# Contrast between consumption during lockdown and without lockdown is 95898.70000000001

# %% [markdown]
# Visualization

# %%
num1=float((list1[2]+list1[3]+list1[4]))
num2=float((list2[2]+list2[3]+list2[4]))
list3=[]
list4=[]
list4.append(num1)
list4.append(num2)
list3.append('befor lockdown')
list3.append('during lockdown')

# %%
plt.figure(figsize = (5, 5))
plt.bar(list3, list4, color ='maroon',
        width = 0.4)
 
plt.xlabel("period")
plt.ylabel("usages")
plt.title("Compare the values in march-may 2019(befor lock down) and march-may 2020 (during lockdown)")
plt.show()

# %% [markdown]
# Percentage change in consumption during the lockdown(as compared to previous year).

# %%
percent=((num1-num2)/num1)*100
print(f"Percentage change in consumption during the lockdown(as compared to previous year) is {percent} %")
# Out:
# Percentage change in consumption during the lockdown(as compared to previous year) is 31.471873149894787 %

# %% [markdown]
# What is the highest value reached by each state at any time of the year in 2019?

# %%
data.head(2)
# Out:
#         Date  Punjab  Haryana  Rajasthan  Delhi     UP  Uttarakhand     HP  \
# 0 2019-01-01   121.3    134.5      230.2   83.0  315.2         38.3  29.17
# 1 2019-01-02   119.9    130.3      234.1   85.8  313.9         40.7  30.00
#
#     J&K  Chandigarh  ...  Arunachal Pradesh  Assam  Manipur  Meghalaya  \
# 0  51.2         4.8  ...                2.0   22.3      2.5        5.9
# 1  52.5         5.0  ...                2.1   21.7      2.7        6.1
#
#    Mizoram  Nagaland  Tripura  year  month  day
# 0      1.7       2.0      3.3  2019      1    1
# 1      1.9       2.2      3.4  2019      1    2
#
# [2 rows x 37 columns]

# %%
table10=data[data["year"]!=2020]

# %%
states=list(table10.columns)
states.remove('year')
states.remove('month')
states.remove('day')

# %%
for i in states:
    x=max(table10[i])
    print(f"the highest value reached by state {i} \t in \t 2019 is \t {x}")
# Out:
# the highest value reached by state Date 	 in 	 2019 is 	 2019-12-31 00:00:00
# the highest value reached by state Punjab 	 in 	 2019 is 	 286.0
# the highest value reached by state Haryana 	 in 	 2019 is 	 224.5
# the highest value reached by state Rajasthan 	 in 	 2019 is 	 278.0
# the highest value reached by state Delhi 	 in 	 2019 is 	 139.1
# the highest value reached by state UP 	 in 	 2019 is 	 469.0
# the highest value reached by state Uttarakhand 	 in 	 2019 is 	 53.2
# the highest value reached by state HP 	 in 	 2019 is 	 34.0
# the highest value reached by state J&K 	 in 	 2019 is 	 54.1
# the highest value reached by state Chandigarh 	 in 	 2019 is 	 6.8
# the highest value reached by state Chhattisgarh 	 in 	 2019 is 	 111.6
# the highest value reached by state Gujarat 	 in 	 2019 is 	 398.0
# the highest value reached by state MP 	 in 	 2019 is 	 272.3
# the highest value reached by state Maharashtra 	 in 	 2019 is 	 522.1
# the highest value reached by state Goa 	 in 	 2019 is 	 14.0
# the highest value reached by state DNH 	 in 	 2019 is 	 19.4
# the highest value reached by state Andhra Pradesh 	 in 	 2019 is 	 205.1
# the highest value reached by state Telangana 	 in 	 2019 is 	 256.2
# the highest value reached by state Karnataka 	 in 	 2019 is 	 273.3
# the highest value reached by state Kerala 	 in 	 2019 is 	 89.4
# the highest value reached by state Tamil Nadu 	 in 	 2019 is 	 365.3
# the highest value reached by state Pondy 	 in 	 2019 is 	 9.7
# the highest value reached by state Bihar 	 in 	 2019 is 	 117.9
# the highest value reached by state Jharkhand 	 in 	 2019 is 	 28.9
# the highest value reached by state Odisha 	 in 	 2019 is 	 109.6
# the highest value reached by state West Bengal 	 in 	 2019 is 	 198.1
# the highest value reached by state Sikkim 	 in 	 2019 is 	 2.8
# the highest value reached by state Arunachal Pradesh 	 in 	 2019 is 	 2.6
# the highest value reached by state Assam 	 in 	 2019 is 	 38.0
# the highest value reached by state Manipur 	 in 	 2019 is 	 3.2
# the highest value reached by state Meghalaya 	 in 	 2019 is 	 6.9
# the highest value reached by state Mizoram 	 in 	 2019 is 	 2.2
# the highest value reached by state Nagaland 	 in 	 2019 is 	 2.7
# the highest value reached by state Tripura 	 in 	 2019 is 	 6.6

# %%
dict3=dict()
for i in states:
    x=max(table10[i])
    dict3.update({i:x})
    
table11=pd.DataFrame.from_dict(dict3,orient="index")
table11.rename(columns={0:"highest value reached"},inplace=True)
table11.head(3)
# Out:
#         highest value reached
# Date      2019-12-31 00:00:00
# Punjab                  286.0
# Haryana                 224.5

# %% [markdown]
# What is the lowest value reached by each state at any time of the year in 2019?

# %%
for i in states:
    x=min(table10[i])
    print(f"the least value reached by state {i} \t in \t 2019 is \t {x}")
# Out:
# the least value reached by state Date 	 in 	 2019 is 	 2019-01-01 00:00:00
# the least value reached by state Punjab 	 in 	 2019 is 	 56.1
# the least value reached by state Haryana 	 in 	 2019 is 	 64.8
# the least value reached by state Rajasthan 	 in 	 2019 is 	 105.8
# the least value reached by state Delhi 	 in 	 2019 is 	 41.8
# the least value reached by state UP 	 in 	 2019 is 	 186.8
# the least value reached by state Uttarakhand 	 in 	 2019 is 	 16.5
# the least value reached by state HP 	 in 	 2019 is 	 11.8
# the least value reached by state J&K 	 in 	 2019 is 	 30.1
# the least value reached by state Chandigarh 	 in 	 2019 is 	 2.2
# the least value reached by state Chhattisgarh 	 in 	 2019 is 	 37.2
# the least value reached by state Gujarat 	 in 	 2019 is 	 192.3
# the least value reached by state MP 	 in 	 2019 is 	 131.8
# the least value reached by state Maharashtra 	 in 	 2019 is 	 305.6
# the least value reached by state Goa 	 in 	 2019 is 	 6.2
# the least value reached by state DNH 	 in 	 2019 is 	 1.3
# the least value reached by state Andhra Pradesh 	 in 	 2019 is 	 142.2
# the least value reached by state Telangana 	 in 	 2019 is 	 130.5
# the least value reached by state Karnataka 	 in 	 2019 is 	 121.0
# the least value reached by state Kerala 	 in 	 2019 is 	 55.0
# the least value reached by state Tamil Nadu 	 in 	 2019 is 	 195.7
# the least value reached by state Pondy 	 in 	 2019 is 	 4.0
# the least value reached by state Bihar 	 in 	 2019 is 	 43.5
# the least value reached by state Jharkhand 	 in 	 2019 is 	 17.4
# the least value reached by state Odisha 	 in 	 2019 is 	 51.1
# the least value reached by state West Bengal 	 in 	 2019 is 	 51.5
# the least value reached by state Sikkim 	 in 	 2019 is 	 0.5
# the least value reached by state Arunachal Pradesh 	 in 	 2019 is 	 1.2
# the least value reached by state Assam 	 in 	 2019 is 	 14.3
# the least value reached by state Manipur 	 in 	 2019 is 	 1.5
# the least value reached by state Meghalaya 	 in 	 2019 is 	 3.2
# the least value reached by state Mizoram 	 in 	 2019 is 	 1.3
# the least value reached by state Nagaland 	 in 	 2019 is 	 1.7
# the least value reached by state Tripura 	 in 	 2019 is 	 2.4

# %%
dict4=dict()
for i in states:
    x=min(table10[i])
    dict4.update({i:x})
    
table12=pd.DataFrame.from_dict(dict4,orient="index")
table12.rename(columns={0:"least value reached"},inplace=True)
table12.head(3)
# Out:
#          least value reached
# Date     2019-01-01 00:00:00
# Punjab                  56.1
# Haryana                 64.8
